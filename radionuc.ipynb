# %%
import pandas as pd
import matplotlib.pyplot as plt   
import numpy as np 
import seaborn as sns

csv_file_path2 = 'dati/radionuc/O15_entering_particles.csv'

df_C11 = pd.read_csv(csv_file_path1, delimiter=',', header=None, names=['Energy', 'X', 'Y', 'Z','evt'])
df_O15 = pd.read_csv(csv_file_path2, delimiter=',', header=None, names=['Energy', 'X', 'Y', 'Z','evt'])


sns.scatterplot(df_C11['X'], df_C11['Y'], label='C11',)
plt.xlim(-150, 150)
plt.ylim(-100, 100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [21], line 12
#       8 df_C11 = pd.read_csv(csv_file_path1, delimiter=',', header=None, names=['Energy', 'X', 'Y', 'Z','evt'])
#       9 df_O15 = pd.read_csv(csv_file_path2, delimiter=',', header=None, names=['Energy', 'X', 'Y', 'Z','evt'])
# ---> 12 sns.scatterplot(df_C11['X'], df_C11['Y'], label='C11',)
#      13 plt.xlim(-150, 150)
#      14 plt.ylim(-100, 100)
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
plt.hist2d(df_C11['X'], df_C11['Y'], bins=(30,30), cmap='viridis',range=[[-150,150],[-100,100]])
plt.colorbar()
plt.show()

# %%
import seaborn as sns

sns.kdeplot(x=df_C11['X'], y=df_C11['Y'], cmap='viridis', fill=True, thresh=0, levels=100,common_grid=True,) 
plt.title('C11')
plt.xlim(-150,150)
plt.ylim(-100,100)
plt.show()

# %%
print(np.shape(df_C11['X']))
# Out:
# (797,)

# %%
plt.scatter(df_O15['X'], df_O15['Y'], label='O15')
plt.xlim(-150,150)
plt.ylim(-100,100)
plt.show()

# %%
plt.hist2d(df_O15['X'], df_O15['Y'], bins=(30,30), cmap='viridis',range=[[-150,150],[-100,100]])
plt.colorbar()
plt.show()

# %%
sns.kdeplot(x=df_O15['X'], y=df_O15['Y'], cmap='viridis', fill=True, thresh=0, levels=100,common_grid=True)
plt.title('O15')
plt.xlim(-150,150)
plt.ylim(-100,100)
plt.show()
